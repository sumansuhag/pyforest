# %%
df=pd.read_csv("http://electronic-card-transactions-may-2024-csv-tables.xlsx.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\OneDrive\Documents\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\OneDrive\Documents\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\OneDrive\Documents\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# ...

# %%
active_imports()
# Out:
# import pandas as pd
# ['import pandas as pd']

# %%
list =[1,2,3,4,5]
list2=[6,7,8,9,10]

# %%
plt.plot(list,list2)
plt.xlabel("xaxis")
plt.ylabel("yaxis")
plt.show()

# %%
active_imports()
# Out:
# import matplotlib.pyplot as plt
# import pandas as pd
# ['import matplotlib.pyplot as plt', 'import pandas as pd']

# %%
np.array([1,2,3,4,5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
df1=pd.read_csv("http://electronic-card-transactions-may-2024-csv-tables.xlsx.csv")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\OneDrive\Documents\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File ~\OneDrive\Documents\Lib\http\client.py:1286, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1285 """Send a complete request to the server."""
# -> 1286 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\OneDrive\Documents\Lib\http\client.py:1332, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1331     body = _encode(body, 'body')
# ...

# %%
df.head(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.head(df)
#
# NameError: name 'df' is not defined
